# %%
import json

def output(filename,mean,best_chomosome,fitness_best_chromo,no_sensors_best,coverage_best_chromo,connectivity_best_chromo,fitness_worst_chromo,no_sensors_worst,coverage_worst_chromo,connectivity_worst_chromo):
	"""print("mean")
			print(mean)
			print("best_chomosome")
			print(best_chomosome)
			print("fitness_best_chromo")
			print(fitness_best_chromo)
			print("no_sensors_best")
			print(no_sensors_best)
			print("coverage_best_chromo")
			print(coverage_best_chromo)
			print("connectivity_best_chromo")
			print(connectivity_best_chromo)
			print("fitness_worst_chromo")
			print(fitness_worst_chromo)
			print("no_sensors_worst")
			print(no_sensors_worst)
			print("coverage_worst_chromo")
			print(coverage_worst_chromo)
			print("connectivity_worst_chromo")
			print(connectivity_worst_chromo)"""

	"""f=open("result.txt","a+")"""
	data={"mean":str(mean),"best_chomosome":str(best_chomosome),"fitness_best_chromo":str(fitness_best_chromo),"no_sensors_best":str(no_sensors_best),"coverage_best_chromo":str(coverage_best_chromo),"connectivity_best_chromo":str(connectivity_best_chromo),"fitness_worst_chromo":str(fitness_worst_chromo),"no_sensors_worst":str(no_sensors_worst),"coverage_worst_chromo":str(coverage_worst_chromo),"connectivity_worst_chromo":str(connectivity_worst_chromo)}
	with open(filename, "+a") as outfile: 
		json.dump(data, outfile)
		outfile.write("\n") 
	"""f.write("mean  :  ")
			f.write(str(mean))
			f.write("\n")
			f.write("best_chomosome  :  ")
			f.write(str(best_chomosome))
			f.write("\n")
			f.write("fitness_best_chromo  :  ")
			f.write(str(fitness_best_chromo))
			f.write("\n")
			f.write("no_sensors_best  :  ")
			f.write(str(no_sensors_best))
			f.write("\n")
			f.write("coverage_best_chromo  :  ")
			f.write(str(coverage_best_chromo))
			f.write("\n")
			f.write("connectivity_best_chromo  :  ")
			f.write(str(connectivity_best_chromo))
			f.write("\n")
			f.write("fitness_worst_chromo  :  ")
			f.write(str(fitness_worst_chromo))
			f.write("\n")
			f.write("no_sensors_worst  :  ")
			f.write(str(no_sensors_worst))
			f.write("\n")
			f.write("coverage_worst_chromo  :  ")
			f.write(str(coverage_worst_chromo))
			f.write("\n")
			f.write("connectivity_worst_chromo  :  ")
			f.write(str(connectivity_worst_chromo))
			f.write("\n\n\n\n\n\n")"""
	"""f.close()"""
